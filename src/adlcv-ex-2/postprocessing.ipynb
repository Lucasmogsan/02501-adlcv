# %% [markdown]
# Visualize attention map of trained ViT

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import torchvision
from torchinfo import summary
from imageclassification import prepare_dataloaders
from vit import ViT

# %% [markdown]
# ## Load model

# %%
# Load the model
model = ViT(image_size=(32,32), patch_size=(4,4), channels=3, 
            embed_dim=128, num_heads=4, num_layers=4,
            pos_enc='learnable', pool='cls', dropout=0.3, fc_dim=None, 
            num_classes=2
            )
model.load_state_dict(torch.load('model.pth'))

batch_size = 16
summary(model, input_size=(batch_size, 3, 32, 32))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ViT                                      [16, 2]                   8,448
# ├─Sequential: 1-1                        [16, 64, 128]             --
# │    └─Rearrange: 2-1                    [16, 64, 48]              --
# │    └─LayerNorm: 2-2                    [16, 64, 48]              96
# │    └─Linear: 2-3                       [16, 64, 128]             6,272
# │    └─LayerNorm: 2-4                    [16, 64, 128]             256
# ├─Dropout: 1-2                           [16, 65, 128]             --
# ├─Sequential: 1-3                        [16, 65, 128]             --
# │    └─EncoderBlock: 2-5                 [16, 65, 128]             --
# │    │    └─Attention: 3-1               [16, 65, 128]             65,664
# │    │    └─LayerNorm: 3-2               [16, 65, 128]             256
# │    │    └─Dropout: 3-3                 [16, 65, 128]             --
# │    │    └─Sequential: 3-4              [16, 65, 128]             131,968
# │    │    └─LayerNorm: 3-5               [16, 65, 128]             256
# │    │    └─Dropout: 3-6                 [16, 65, 128]             --
# │    └─EncoderBlock: 2-6                 [16, 65, 128]             --
# │    │    └─Attention: 3-7               [16, 65, 128]             65,664
# │    │    └─LayerNorm: 3-8               [16, 65, 128]             256
# │    │    └─Dropout: 3-9                 [16, 65, 128]             --
# │    │    └─Sequential: 3-10             [16, 65, 128]             131,968
# │    │    └─LayerNorm: 3-11              [16, 65, 128]             256
# │    │    └─Dropout: 3-12                [16, 65, 128]             --
# │    └─EncoderBlock: 2-7                 [16, 65, 128]             --
# │    │    └─Attention: 3-13              [16, 65, 128]             65,664
# │    │    └─LayerNorm: 3-14              [16, 65, 128]             256
# │    │    └─Dropout: 3-15                [16, 65, 128]             --
# │    │    └─Sequential: 3-16             [16, 65, 128]             131,968
# │    │    └─LayerNorm: 3-17              [16, 65, 128]             256
# │    │    └─Dropout: 3-18                [16, 65, 128]             --
# │    └─EncoderBlock: 2-8                 [16, 65, 128]             --
# │    │    └─Attention: 3-19              [16, 65, 128]             65,664
# │    │    └─LayerNorm: 3-20              [16, 65, 128]             256
# │    │    └─Dropout: 3-21                [16, 65, 128]             --
# │    │    └─Sequential: 3-22             [16, 65, 128]             131,968
# │    │    └─LayerNorm: 3-23              [16, 65, 128]             256
# │    │    └─Dropout: 3-24                [16, 65, 128]             --
# ├─Linear: 1-4                            [16, 2]                   258
# ==========================================================================================
# Total params: 807,906
# Trainable params: 807,906
# Non-trainable params: 0
# Total mult-adds (M): 12.79
# ==========================================================================================
# Input size (MB): 0.20
# Forward/backward pass size (MB): 53.61
# Params size (MB): 3.20
# Estimated Total Size (MB): 57.00
# ==========================================================================================

# %%
# View the model keys (from the state_dict)
model = torch.load('model.pth')
print(model.keys())

# Show only the ones that contain the word "attention"
attention_keys = [k for k in model.keys() if 'attention' in k]
print(attention_keys)

# Find the models attention weights
attention_weights = model['transformer_blocks.2.attention.o_projection.weight']
print(attention_weights.shape)

# Plot the attention weights
plt.figure(figsize=(10, 10))
plt.matshow(attention_weights.cpu(), cmap='viridis')
plt.show()
# Out:
# odict_keys(['cls_token', 'positional_embedding', 'to_patch_embedding.1.weight', 'to_patch_embedding.1.bias', 'to_patch_embedding.2.weight', 'to_patch_embedding.2.bias', 'to_patch_embedding.3.weight', 'to_patch_embedding.3.bias', 'transformer_blocks.0.attention.k_projection.weight', 'transformer_blocks.0.attention.q_projection.weight', 'transformer_blocks.0.attention.v_projeciton.weight', 'transformer_blocks.0.attention.o_projection.weight', 'transformer_blocks.0.attention.o_projection.bias', 'transformer_blocks.0.layernorm1.weight', 'transformer_blocks.0.layernorm1.bias', 'transformer_blocks.0.layernorm2.weight', 'transformer_blocks.0.layernorm2.bias', 'transformer_blocks.0.fc.0.weight', 'transformer_blocks.0.fc.0.bias', 'transformer_blocks.0.fc.1.weight', 'transformer_blocks.0.fc.1.bias', 'transformer_blocks.0.fc.3.weight', 'transformer_blocks.0.fc.3.bias', 'transformer_blocks.1.attention.k_projection.weight', 'transformer_blocks.1.attention.q_projection.weight', 'transformer_blocks.1.attention.v_projeciton.weight', 'transformer_blocks.1.attention.o_projection.weight', 'transformer_blocks.1.attention.o_projection.bias', 'transformer_blocks.1.layernorm1.weight', 'transformer_blocks.1.layernorm1.bias', 'transformer_blocks.1.layernorm2.weight', 'transformer_blocks.1.layernorm2.bias', 'transformer_blocks.1.fc.0.weight', 'transformer_blocks.1.fc.0.bias', 'transformer_blocks.1.fc.1.weight', 'transformer_blocks.1.fc.1.bias', 'transformer_blocks.1.fc.3.weight', 'transformer_blocks.1.fc.3.bias', 'transformer_blocks.2.attention.k_projection.weight', 'transformer_blocks.2.attention.q_projection.weight', 'transformer_blocks.2.attention.v_projeciton.weight', 'transformer_blocks.2.attention.o_projection.weight', 'transformer_blocks.2.attention.o_projection.bias', 'transformer_blocks.2.layernorm1.weight', 'transformer_blocks.2.layernorm1.bias', 'transformer_blocks.2.layernorm2.weight', 'transformer_blocks.2.layernorm2.bias', 'transformer_blocks.2.fc.0.weight', 'transformer_blocks.2.fc.0.bias', 'transformer_blocks.2.fc.1.weight', 'transformer_blocks.2.fc.1.bias', 'transformer_blocks.2.fc.3.weight', 'transformer_blocks.2.fc.3.bias', 'transformer_blocks.3.attention.k_projection.weight', 'transformer_blocks.3.attention.q_projection.weight', 'transformer_blocks.3.attention.v_projeciton.weight', 'transformer_blocks.3.attention.o_projection.weight', 'transformer_blocks.3.attention.o_projection.bias', 'transformer_blocks.3.layernorm1.weight', 'transformer_blocks.3.layernorm1.bias', 'transformer_blocks.3.layernorm2.weight', 'transformer_blocks.3.layernorm2.bias', 'transformer_blocks.3.fc.0.weight', 'transformer_blocks.3.fc.0.bias', 'transformer_blocks.3.fc.1.weight', 'transformer_blocks.3.fc.1.bias', 'transformer_blocks.3.fc.3.weight', 'transformer_blocks.3.fc.3.bias', 'classifier.weight', 'classifier.bias'])
# ['transformer_blocks.0.attention.k_projection.weight', 'transformer_blocks.0.attention.q_projection.weight', 'transformer_blocks.0.attention.v_projeciton.weight', 'transformer_blocks.0.attention.o_projection.weight', 'transformer_blocks.0.attention.o_projection.bias', 'transformer_blocks.1.attention.k_projection.weight', 'transformer_blocks.1.attention.q_projection.weight', 'transformer_blocks.1.attention.v_projeciton.weight', 'transformer_blocks.1.attention.o_projection.weight', 'transformer_blocks.1.attention.o_projection.bias', 'transformer_blocks.2.attention.k_projection.weight', 'transformer_blocks.2.attention.q_projection.weight', 'transformer_blocks.2.attention.v_projeciton.weight', 'transformer_blocks.2.attention.o_projection.weight', 'transformer_blocks.2.attention.o_projection.bias', 'transformer_blocks.3.attention.k_projection.weight', 'transformer_blocks.3.attention.q_projection.weight', 'transformer_blocks.3.attention.v_projeciton.weight', 'transformer_blocks.3.attention.o_projection.weight', 'transformer_blocks.3.attention.o_projection.bias']
# torch.Size([128, 128])

# %% [markdown]
# ## Load data

# %%
train_iter, test_iter, _, _ = prepare_dataloaders(batch_size=batch_size)
# Take a single batch from the test set
image, label = next(iter(test_iter))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
print(image[0].shape)

# show the originial images
img_grid = torchvision.utils.make_grid(image, nrow=batch_size, 
                                        normalize=True, pad_value=0.9
    )
# plot the image
plt.figure(figsize=(20, 20))
plt.imshow(np.transpose(img_grid, (1, 2, 0)))
# Out:
# torch.Size([3, 32, 32])

# %% [markdown]
# # Run through model

# %%
model.eval()

# %%
# Load the model
model = ViT(image_size=(32,32), patch_size=(4,4), channels=3, 
            embed_dim=128, num_heads=4, num_layers=4,
            pos_enc='learnable', pool='cls', dropout=0.3, fc_dim=None, 
            num_classes=2
            )
model.load_state_dict(torch.load('model.pth'))

out = model(image)
